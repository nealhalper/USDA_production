# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
demo_fruitnut = pd.read_csv('../data/fruittreenuttotals_demographics.csv')
demo_berries = pd.read_csv('../data/demographics_berries.csv')
demo_citrus = pd.read_csv('../data/demographics_citrus.csv')
demo_vegetables = pd.read_csv('../data/demographics_vegetables.csv')

# %%
berry_org_types = demo_berries.loc[(demo_berries['Domain'] == 'ORGANIZATION') & (demo_berries['Data Item'] == 'BERRY TOTALS - OPERATIONS WITH SALES')]
berry_org_types
# Out:
#       Program  Year Period  Week Ending Geo Level      State  State ANSI  \
# 32     CENSUS  2022   YEAR          NaN  NATIONAL   US TOTAL         NaN
# 33     CENSUS  2022   YEAR          NaN  NATIONAL   US TOTAL         NaN
# 34     CENSUS  2022   YEAR          NaN  NATIONAL   US TOTAL         NaN
# 35     CENSUS  2022   YEAR          NaN  NATIONAL   US TOTAL         NaN
# 36     CENSUS  2022   YEAR          NaN  NATIONAL   US TOTAL         NaN
# ...       ...   ...    ...          ...       ...        ...         ...
# 18728  CENSUS  2012   YEAR          NaN     STATE  WISCONSIN        55.0
# 18891  CENSUS  2012   YEAR          NaN     STATE    WYOMING        56.0
# 18892  CENSUS  2012   YEAR          NaN     STATE    WYOMING        56.0
# 18893  CENSUS  2012   YEAR          NaN     STATE    WYOMING        56.0
# 18894  CENSUS  2012   YEAR          NaN     STATE    WYOMING        56.0
#
#        Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 32             NaN               NaN     NaN  ...       NaN     NaN
# 33             NaN               NaN     NaN  ...       NaN     NaN
# 34             NaN               NaN     NaN  ...       NaN     NaN
# 35             NaN               NaN     NaN  ...       NaN     NaN
# 36             NaN               NaN     NaN  ...       NaN     NaN
# ...            ...               ...     ...  ...       ...     ...
# 18728          NaN               NaN     NaN  ...       NaN     NaN
# 18891          NaN               NaN     NaN  ...       NaN     NaN
# 18892          NaN               NaN     NaN  ...       NaN     NaN
# 18893          NaN               NaN     NaN  ...       NaN     NaN
# 18894          NaN               NaN     NaN  ...       NaN     NaN
#
#        watershed_code  Watershed     Commodity  \
# 32                  0        NaN  BERRY TOTALS
# 33                  0        NaN  BERRY TOTALS
# 34                  0        NaN  BERRY TOTALS
# 35                  0        NaN  BERRY TOTALS
# 36                  0        NaN  BERRY TOTALS
# ...               ...        ...           ...
# 18728               0        NaN  BERRY TOTALS
# 18891               0        NaN  BERRY TOTALS
# 18892               0        NaN  BERRY TOTALS
# 18893               0        NaN  BERRY TOTALS
# 18894               0        NaN  BERRY TOTALS
#
#                                   Data Item        Domain  \
# 32     BERRY TOTALS - OPERATIONS WITH SALES  ORGANIZATION
# 33     BERRY TOTALS - OPERATIONS WITH SALES  ORGANIZATION
# 34     BERRY TOTALS - OPERATIONS WITH SALES  ORGANIZATION
# 35     BERRY TOTALS - OPERATIONS WITH SALES  ORGANIZATION
# 36     BERRY TOTALS - OPERATIONS WITH SALES  ORGANIZATION
# ...                                     ...           ...
# 18728  BERRY TOTALS - OPERATIONS WITH SALES  ORGANIZATION
# 18891  BERRY TOTALS - OPERATIONS WITH SALES  ORGANIZATION
# 18892  BERRY TOTALS - OPERATIONS WITH SALES  ORGANIZATION
# 18893  BERRY TOTALS - OPERATIONS WITH SALES  ORGANIZATION
# 18894  BERRY TOTALS - OPERATIONS WITH SALES  ORGANIZATION
#
#                                          Domain Category  Value CV (%)
# 32             ORGANIZATION: (TAX PURPOSES, CORPORATION)  3,977    5.7
# 33     ORGANIZATION: (TAX PURPOSES, CORPORATION, (EXC...    661    6.5
# 34     ORGANIZATION: (TAX PURPOSES, CORPORATION, (EXC...    633    6.7
# 35     ORGANIZATION: (TAX PURPOSES, CORPORATION, FAMI...  3,316    6.0
# 36     ORGANIZATION: (TAX PURPOSES, CORPORATION, FAMI...  3,252    6.2
# ...                                                  ...    ...    ...
# 18728  ORGANIZATION: (TAX PURPOSES, PARTNERSHIP, REGI...     70    8.0
# 18891          ORGANIZATION: (TAX PURPOSES, CORPORATION)      2   94.9
# 18892  ORGANIZATION: (TAX PURPOSES, CORPORATION, FAMI...      2   94.9
# 18893  ORGANIZATION: (TAX PURPOSES, CORPORATION, FAMI...      2   94.9
# 18894  ORGANIZATION: (TAX PURPOSES, FAMILY & INDIVIDUAL)      6   61.2
#
# [1256 rows x 21 columns]

# %%
berry_org_types.to_csv(path_or_buf = 'berry_org_types.csv', index = False)

# %%
veg_org_types = demo_vegetables.loc[(demo_vegetables['Domain'] == 'ORGANIZATION') & (demo_vegetables['Data Item'] == 'VEGETABLE TOTALS, INCL SEEDS & TRANSPLANTS, IN THE OPEN - OPERATIONS WITH SALES')]
veg_org_types.to_csv(path_or_buf = 'veg_org_types.csv', index = False)

# %%
demo_vegetables['Domain Category'].loc[(demo_vegetables['Domain'] == 'ORGANIZATION')].unique()
# Out:
# array(['ORGANIZATION: (TAX PURPOSES, CORPORATION)',
#        'ORGANIZATION: (TAX PURPOSES, CORPORATION, (EXCL FAMILY HELD))',
#        'ORGANIZATION: (TAX PURPOSES, CORPORATION, (EXCL FAMILY HELD), LE 10 STOCKHOLDERS)',
#        'ORGANIZATION: (TAX PURPOSES, CORPORATION, FAMILY HELD)',
#        'ORGANIZATION: (TAX PURPOSES, CORPORATION, FAMILY HELD, LE 10 STOCKHOLDERS)',
#        'ORGANIZATION: (TAX PURPOSES, FAMILY & INDIVIDUAL)',
#        'ORGANIZATION: (TAX PURPOSES, INSTITUTIONAL & RESEARCH & RESERVATION & OTHER)',
#        'ORGANIZATION: (TAX PURPOSES, PARTNERSHIP)',
#        'ORGANIZATION: (TAX PURPOSES, PARTNERSHIP, REGISTERED UNDER STATE LAW)'],
#       dtype=object)
